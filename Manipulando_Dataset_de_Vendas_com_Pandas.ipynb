# %% [markdown]
# <a href="https://colab.research.google.com/github/cibelemoraes/Ci-ncia-de-dados/blob/main/Manipulando_Dataset_de_Vendas_com_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Sales.csv")

# %% [markdown]
# vizualizando as 5 primeiras linhas

# %%
df.head()
# Out:
#    SalesId  StoreId  ProductId        Date  UnitPrice  Quantity
# 0    82319    22726        590  2019-12-02     0.0525        93
# 1    15022    21754        390  2017-11-19     5.1100        28
# 2    11624    71053        883  2020-07-13     7.3675        33
# 3    63101    22914        658  2019-05-12     2.0825        76
# 4    29702    22623        632  2020-07-20     0.6475         8

# %%
df.rename(columns={"SalesId":"IdVendas",	"StoreId":"Idlojas",	"ProductId":"ProdutosID",	"Date":"DatadeVendas",	"UnitPrice":"PrecoUni",	"Quantity":"Quantidade"})
# Out:
#         IdVendas  Idlojas  ProdutosID DatadeVendas  PrecoUni  Quantidade
# 0          82319    22726         590   2019-12-02    0.0525          93
# 1          15022    21754         390   2017-11-19    5.1100          28
# 2          11624    71053         883   2020-07-13    7.3675          33
# 3          63101    22914         658   2019-05-12    2.0825          76
# 4          29702    22623         632   2020-07-20    0.6475           8
# ...          ...      ...         ...          ...       ...         ...
# 199995     57660    85123         682   2019-07-01    4.4625          75
# 199996     18783    22727         656   2017-04-18    1.6800          30
# 199997     25064    22912         831   2019-06-10    2.5025          60
# 199998     43683    22622         902   2018-08-06    3.2025          98
# 199999     44211    22749         775   2018-06-22    1.8550          32
#
# [200000 rows x 6 columns]

# %%
df.shape
# Out:
# (200000, 6)

# %%
df.head(10)
# Out:
#    SalesId  StoreId  ProductId        Date  UnitPrice  Quantity
# 0    82319    22726        590  2019-12-02     0.0525        93
# 1    15022    21754        390  2017-11-19     5.1100        28
# 2    11624    71053        883  2020-07-13     7.3675        33
# 3    63101    22914        658  2019-05-12     2.0825        76
# 4    29702    22623        632  2020-07-20     0.6475         8
# 5    35660    22749        170  2019-09-30     5.6700        93
# 6    69913    22633        444  2017-11-03     0.4375        98
# 7    47278    84969        184  2018-04-17     9.2050        17
# 8    46126    48187        316  2017-10-13     3.3950        47
# 9    69718    22726        972  2018-09-12     1.5925        43

# %%
df.dtypes
# Out:
# SalesId        int64
# StoreId        int64
# ProductId      int64
# Date          object
# UnitPrice    float64
# Quantity       int64
# dtype: object

# %% [markdown]
# Informações estatisticas sobre o meu DataSet

# %%
df.describe()
# Out:
#              SalesId        StoreId      ProductId      UnitPrice  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean    49997.590185   33720.734235     500.587255       3.313406
# std     23095.103021   23209.383882     288.611347       2.812360
# min     10000.000000   10002.000000       1.000000       0.017500
# 25%     29959.000000   21791.000000     250.000000       1.277500
# 50%     50048.000000   22728.000000     501.000000       2.765000
# 75%     70043.000000   22960.000000     751.000000       4.287500
# max     90000.000000   85123.000000    1000.000000      21.157500
#
#             Quantity
# count  200000.000000
# mean       50.383910
# std        28.870702
# min         1.000000
# 25%        25.000000
# 50%        50.000000
# 75%        75.000000
# max       100.000000

# %% [markdown]
# localizando uma loja especifica

# %%
df["StoreId"].unique()
# Out:
# array([22726, 21754, 71053, 22914, 22623, 22749, 22633, 84969, 48187,
#        21755, 22913, 37444, 22748, 85123, 22632, 21777, 22745, 10002,
#        84879, 22727, 22310, 22960, 22622, 21724, 21883, 21730, 21791,
#        22912, 21756, 21035, 22728, 84406, 84029, 22752])

# %% [markdown]
# mostrando produtos de uma loja especifica

# %%
Loja = df.loc[df["StoreId"] == 21754 ]
Loja.head()
# Out:
#      SalesId  StoreId  ProductId        Date  UnitPrice  Quantity
# 1      15022    21754        390  2017-11-19      5.110        28
# 43     87676    21754        604  2018-04-07      2.345        91
# 69     73573    21754        286  2020-09-06      4.900        12
# 249    31068    21754        778  2020-05-05      8.470        30
# 275    52388    21754        262  2020-03-20      1.155        19

# %%
df.groupby("StoreId")["Quantity"].nunique(30)
# Out:
# StoreId
# 10002    100
# 21035    100
# 21724    100
# 21730    100
# 21754    100
# 21755    100
# 21756    100
# 21777    100
# 21791    100
# 21883    100
# 22310    100
# 22622    100
# 22623    100
# 22632    100
# 22633    100
# 22726    100
# 22727    100
# 22728    100
# 22745    100
# 22748    100
# 22749    100
# 22752    100
# 22912    100
# 22913    100
# 22914    100
# 22960    100
# 37444    100
# 48187    100
# 71053    100
# 84029    100
# 84406    100
# 84879    100
# 84969    100
# 85123    100
# Name: Quantity, dtype: int64

# %% [markdown]
# média de quantidades em relação as datas

# %%
df.groupby("Date")["Quantity"].mean()
# Out:
# Date
# 2017-01-01    52.906542
# 2017-01-02    48.162393
# 2017-01-03    50.852459
# 2017-01-04    50.966667
# 2017-01-05    47.765152
#                 ...
# 2020-12-26    51.694030
# 2020-12-27    54.584071
# 2020-12-28    52.573427
# 2020-12-29    50.601626
# 2020-12-30    49.631148
# Name: Quantity, Length: 1460, dtype: float64

# %%
df["UnitPrice"].mean()
# Out:
# 3.313405637499999

# %%
df["UnitPrice"].sum()
# Out:
# 662681.1274999998
