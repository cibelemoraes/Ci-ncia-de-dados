# %% [markdown]
# <a href="https://colab.research.google.com/github/cibelemoraes/Ci-ncia-de-dados/blob/main/Trabalhando_com_Planilhas_e_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#leitura dos arquivos
df1 = pd.read_excel("/content/03_02_Clientes.xlsx")
df2 = pd.read_excel("/content/04_03_População 2001 a 2018.xlsx")
df3 = pd.read_excel("/content/04_07_População 2019.xlsx")

# %%
df = pd.concat([df1,df3])

# %% [markdown]
# exibindo as 5 primeiras linhas

# %%
df.head()
# Out:
#    ID Cliente                        Cliente        CEP Data Pedido  \
# 0     26564.0                Luís Rocha Dias  99950-000  2018-12-18
# 1     20201.0           Ágatha Carvalho Dias  90690-380  2018-12-01
# 2     13350.0         Sophia Correia Almeida  90510-040  2019-01-16
# 3     21163.0        Giovana Rodrigues Silva  90200-310  2018-11-30
# 4     23381.0  Gabrielle Ferreira Cavalcanti  89300-000  2018-11-30
#
#   Unidades da Federação Região Publicação  Anos  Valor
# 0                   NaN    NaN        NaT   NaN    NaN
# 1                   NaN    NaN        NaT   NaN    NaN
# 2                   NaN    NaN        NaT   NaN    NaN
# 3                   NaN    NaN        NaT   NaN    NaN
# 4                   NaN    NaN        NaT   NaN    NaN

# %%
df1.head()
# Out:
#    ID Cliente                        Cliente        CEP Data Pedido
# 0       26564                Luís Rocha Dias  99950-000  2018-12-18
# 1       20201           Ágatha Carvalho Dias  90690-380  2018-12-01
# 2       13350         Sophia Correia Almeida  90510-040  2019-01-16
# 3       21163        Giovana Rodrigues Silva  90200-310  2018-11-30
# 4       23381  Gabrielle Ferreira Cavalcanti  89300-000  2018-11-30

# %%
df2.head()
# Out:
#   População residente enviada ao Tribunal de Contas da União Unnamed: 1  \
# 0  Brasil, Grandes Regiões e Unidades da Federaçã...                NaN
# 1                                                NaN                NaN
# 2                              Unidades da Federação             Região
# 3                                                NaN                NaN
# 4                                             Brasil             Brasil
#
#             Unnamed: 2   Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6  \
# 0                  NaN          NaN          NaN          NaN          NaN
# 1                  NaN          NaN          NaN          NaN          NaN
# 2           Publicação       2001.0       2002.0       2003.0       2004.0
# 3                  NaN          NaN          NaN          NaN          NaN
# 4  2019-01-02 00:00:00  172385826.0  174632960.0  176871437.0  181581024.0
#
#     Unnamed: 7   Unnamed: 8   Unnamed: 9  ...  Unnamed: 11  Unnamed: 12  \
# ...

# %%
df3.head()
# Out:
#   Unidades da Federação        Região Publicação  Anos    Valor
# 0              Rondônia  Região Norte 2019-01-02  2019  1777225
# 1                  Acre  Região Norte 2019-01-02  2019   881935
# 2              Amazonas  Região Norte 2019-01-02  2019  4144597
# 3               Roraima  Região Norte 2019-01-02  2019   605761
# 4                  Pará  Região Norte 2019-01-02  2019  8602865

# %%
df.tail()
# Out:
#     ID Cliente Cliente  CEP Data Pedido Unidades da Federação  \
# 22         NaN     NaN  NaN         NaT     Rio Grande do Sul
# 23         NaN     NaN  NaN         NaT    Mato Grosso do Sul
# 24         NaN     NaN  NaN         NaT           Mato Grosso
# 25         NaN     NaN  NaN         NaT                 Goiás
# 26         NaN     NaN  NaN         NaT      Distrito Federal
#
#                  Região Publicação    Anos       Valor
# 22           Região Sul 2019-07-26  2019.0  11377239.0
# 23  Região Centro-Oeste 2019-07-26  2019.0   2778986.0
# 24  Região Centro-Oeste 2019-07-26  2019.0   3484466.0
# 25  Região Centro-Oeste 2019-07-26  2019.0   7018354.0
# 26  Região Centro-Oeste 2019-07-26  2019.0   3015268.0

# %%
df.dtypes
# Out:
# ID Cliente                      float64
# Cliente                          object
# CEP                              object
# Data Pedido              datetime64[ns]
# Unidades da Federação            object
# Região                           object
# Publicação               datetime64[ns]
# Anos                            float64
# Valor                           float64
# dtype: object

# %% [markdown]
# alterando o tipo de dado de uma coluna

# %%
df["Publicação"] = df["Publicação"].astype("datetime64[ns]")

# %% [markdown]
# consultando valores nulos nos meus dados

# %%
df.isnull().sum()
# Out:
# Cliente                  0.0
# CEP                      0.0
# Data Pedido              0.0
# Unidades da Federação    0.0
# Região                   0.0
# Publicação               0.0
# Anos                     0.0
# Valor                    0.0
# dtype: float64

# %% [markdown]
# Substituindo Valores Nulos Pela média

# %%
#df["Valor"].fillna(df["Valor"].mean(), inplace=True)

# %%
#df["Anos"].fillna(df["Anos"].mean(), inplace=True)

# %%
#df["Publicação"].fillna(df["Publicação"].mean(), inplace=True)

# %%
#df["Região"].fillna(df["Região"].mean(), inplace=True)

# %%
#df["Unidades da Federação"].fillna(df["Unidades da Federação"].mean(), inplace=True)

# %%
#df["Data Pedido"].fillna(df["Data Pedido"].mean(), inplace=True)

# %%
#df["CEP"].fillna(df["CEP"].mean(), inplace=True)

# %%
#df["Cliente"].fillna(df["Cliente"].mean(), inplace=True)

# %%
#df.drop('ID Cliente', axis=1, inplace=True)

# %%
df1.dropna(how="all", inplace=True)

# %%
df1.head()
# Out:
#    ID Cliente                        Cliente        CEP Data Pedido
# 0       26564                Luís Rocha Dias  99950-000  2018-12-18
# 1       20201           Ágatha Carvalho Dias  90690-380  2018-12-01
# 2       13350         Sophia Correia Almeida  90510-040  2019-01-16
# 3       21163        Giovana Rodrigues Silva  90200-310  2018-11-30
# 4       23381  Gabrielle Ferreira Cavalcanti  89300-000  2018-11-30

# %%
df3.dropna(how="all", inplace=True)

# %%
df3.head()
# Out:
#   Unidades da Federação        Região Publicação  Anos    Valor
# 0              Rondônia  Região Norte 2019-01-02  2019  1777225
# 1                  Acre  Região Norte 2019-01-02  2019   881935
# 2              Amazonas  Região Norte 2019-01-02  2019  4144597
# 3               Roraima  Região Norte 2019-01-02  2019   605761
# 4                  Pará  Região Norte 2019-01-02  2019  8602865

# %%
df = pd.concat([df1,df3])
df.head()
# Out:
#    ID Cliente                        Cliente        CEP Data Pedido  \
# 0     26564.0                Luís Rocha Dias  99950-000  2018-12-18
# 1     20201.0           Ágatha Carvalho Dias  90690-380  2018-12-01
# 2     13350.0         Sophia Correia Almeida  90510-040  2019-01-16
# 3     21163.0        Giovana Rodrigues Silva  90200-310  2018-11-30
# 4     23381.0  Gabrielle Ferreira Cavalcanti  89300-000  2018-11-30
#
#   Unidades da Federação Região Publicação  Anos  Valor
# 0                   NaN    NaN        NaT   NaN    NaN
# 1                   NaN    NaN        NaT   NaN    NaN
# 2                   NaN    NaN        NaT   NaN    NaN
# 3                   NaN    NaN        NaT   NaN    NaN
# 4                   NaN    NaN        NaT   NaN    NaN

# %%
df3["Valor"].max()
# Out:
# 45919049

# %%
df3["Valor"].min()
# Out:
# 605761
